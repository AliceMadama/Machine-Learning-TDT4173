# %% [markdown]
# # Short notebook 1: 146.37, Best Score
#
#
# Group members: Alice Madama 104807, Arianna Cagali 105103, Oliver Sanchez: 568003
#
# Group Name: PCswappers

# %% [markdown]
# Most of the libraries used are common in machine learning, however flaml might be missing, so consider dowloading it before running the notebook.

# %%
import os
import re
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import matplotlib.pyplot as plt
from catboost import CatBoostRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import seaborn as sns
from scipy import stats
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import StandardScaler
from flaml import AutoML
import xgboost
import pickle

# %%
# Add time functions
def add_time_features_std(df, time_column):
    
    # Extract various time features
    df['hour'] = df[time_column].dt.hour
    df['day_of_week'] = df[time_column].dt.dayofweek
    df['month'] = df[time_column].dt.month
    df['day_of_year'] = df[time_column].dt.dayofyear
    df['week_of_year'] = df[time_column].dt.isocalendar().week 
    df['year'] = df[time_column].dt.year

    return df

def add_time_features_cat(df, time_column):
  
    df['sin_hour'] = np.sin(np.pi * df[time_column].dt.hour/24.)
    df['sin_month'] = np.sin(np.pi * df[time_column].dt.month/12.)

    return df

# %%
def add_new_features(df):
    df['SumRad'] = df ['direct_rad:W'] + df['diffuse_rad:W']
    df['SumRad_1h'] = df['direct_rad_1h:J'] + df['diffuse_rad_1h:J']
    df['ClearSkyRatio'] = df['SumRad']/(1+df['clear_sky_rad:W'])
    df['TempDewPoint'] = df['t_1000hPa:K'] - df['dew_point_2m:K']
    
    return df

# %%
def find_strong_correlation_pairs(data, threshold=0.95):
    # Calculate the correlation matrix
    correlation_matrix = data.corr()

    # Find pairs with strong correlation
    strong_correlation_pairs = []
    for i in range(len(correlation_matrix.columns)):
        for j in range(i + 1, len(correlation_matrix.columns)):
            if abs(correlation_matrix.iloc[i, j]) > threshold:
                strong_correlation_pairs.append((correlation_matrix.columns[i], correlation_matrix.columns[j]))

    # Print pairs with strong correlation
    if strong_correlation_pairs:
        print("Pairs with strong correlation:")
        for pair in strong_correlation_pairs:
            print(f"{pair[0]} and {pair[1]} have a correlation of {correlation_matrix[pair[0]][pair[1]]}")
    else:
        print("No strong correlation pairs found.")
    
    print("\n")
    return strong_correlation_pairs

# %%
def clean_outliers_zscore(df, columns, z_threshold):
    cleaned_df = df.copy()
    
    for col in columns:
        z_scores = np.abs((cleaned_df[col] - cleaned_df[col].mean()) / cleaned_df[col].std())
        outliers = z_scores > z_threshold
        cleaned_df.loc[outliers, col] = np.nan  
    
    cleaned_df = cleaned_df.dropna()
    
    return cleaned_df

# %%
# Preprocessing functions

def preprocessing_std(targets, observed, estimated, test):

#Ensure the datetime columns are in datetime format
    targets['time'] = pd.to_datetime(targets['time'])
    observed['date_forecast'] = pd.to_datetime(observed['date_forecast'])
    estimated['date_forecast'] = pd.to_datetime(estimated['date_forecast'])
    test['date_forecast'] = pd.to_datetime(test['date_forecast'])

#Resample date_calc
    date_calc_resampled_ob = estimated.set_index('date_forecast')['date_calc'].resample('1H').first()
    date_calc_resampled_te = test.set_index('date_forecast')['date_calc'].resample('1H').first()

#Convert to pandas dataframe
    date_calc_resampled_ob = date_calc_resampled_ob.to_frame()
    date_calc_resampled_te = date_calc_resampled_te.to_frame()

#Resample dataframes
    observed_resampled = observed.set_index('date_forecast').resample('1H').mean().dropna(how='all').reset_index()
    estimated_resampled = estimated.set_index('date_forecast').resample('1H').mean().dropna(how='all').reset_index()
    test_resampled = test.set_index('date_forecast').resample('1H').mean().dropna(how='all').reset_index()
    
#Merge the obtained results
    estimated_resampled = estimated_resampled.merge(date_calc_resampled_ob, left_on='date_forecast', right_index=True)
    test_resampled = test_resampled.merge(date_calc_resampled_te, left_on='date_forecast', right_index=True)

#Get the 'is_day:idx' feature
    is_day_feature = test_resampled[['date_forecast', 'is_day:idx']]

#Drop constant columns
    const_columns = ['is_day:idx', 'snow_density:kgm3','elevation:m', 'snow_drift:idx']
    test_resampled = test_resampled.drop(columns =const_columns)
    observed_resampled = observed_resampled.drop(columns = const_columns)
    estimated_resampled = estimated_resampled.drop(columns = const_columns)

#Get starting and ending date
    first_date = targets['time'].min()
    last_date = targets['time'].max()

    print('{firs_date}, {second_date}')

#Add time delta variable 
    estimated_resampled['time_dummy'] = (estimated_resampled['date_forecast'] - estimated_resampled['date_forecast'].dt.normalize()).dt.total_seconds() / 3600
    observed_resampled['time_dummy'] = 0
    test_resampled['time_dummy'] = (test_resampled['date_forecast'] - test_resampled['date_forecast'].dt.normalize()).dt.total_seconds() / 3600

    estimated_resampled['time_delta'] = (estimated_resampled['date_calc'] - estimated_resampled['date_forecast']).dt.total_seconds() / 3600
    observed_resampled['time_delta'] = 0  # since observed data is not forecasting ahead
    test_resampled['time_delta'] = (test_resampled['date_calc'] - test['date_forecast']).dt.total_seconds() / 3600

#Add indicator variable for estimated data
    estimated_resampled['is_estimated'] = 1
    observed_resampled['is_estimated'] = 0
    test_resampled['is_estimated'] = 1

#Concatenate data
    weather_df = pd.concat([observed_resampled, estimated_resampled], axis=0).sort_values(by='date_forecast')
    print(weather_df)

    weather_df = weather_df.reset_index(drop=True)

#Remove outliers
#targets=clean_outliers_zscore(targets, ['pv_measurement'], 5)
#Does not improve score

# Merge with target values
    merged_data = pd.merge(targets, weather_df, how='inner', left_on='time', right_on='date_forecast')
    print(merged_data)
    
# Check if merged_data is empty
    print(merged_data)

# Remove rows where 'pv_measurement' is 0
    merged_data = merged_data[merged_data['pv_measurement'] != 0]

# Remove constant stretches
    merged_data['diff'] = merged_data['pv_measurement'].diff().fillna(0)
    merged_data['constant'] = (merged_data['diff'] == 0).astype(int)
    merged_data['block'] = (merged_data['constant'].diff() != 0).astype(int).cumsum()
    block_sizes = merged_data.groupby('block')['constant'].sum()
    constant_blocks = block_sizes[block_sizes > 2].index
    filtered_data = merged_data[~merged_data['block'].isin(constant_blocks)]

#Remove too highly correlated columns
    find_strong_correlation_pairs(merged_data, threshold=0.98)
    
    corr_col = ['pressure_50m:hPa', 
    'pressure_100m:hPa', 
    'sfc_pressure:hPa']

    filtered_data = filtered_data.drop(columns=corr_col)
    test_resampled = test_resampled.drop(columns= corr_col)

# Extract relevant columns from filtered_data
    targets_new = filtered_data[['time', 'pv_measurement']]

# Drop non-feature columns
    filtered_data = filtered_data.drop(columns=['diff', 'constant', 'block', 'time', 'pv_measurement', 'date_calc'])
    test_resampled = test_resampled.drop(columns=['date_calc'])   

# Check if observed_resampled is empty
    print(observed_resampled)

    return filtered_data, test_resampled, is_day_feature, targets_new

# %%
def process_location_flaml(X, y, X_test):
   
    # Initialize the AutoML object
    automl = AutoML()

    # Search for the best regression model and hyperparameters
    automl.fit(X_train=X, y_train=y['pv_measurement'], task="regression", time_budget = 60, metric = 'mae', estimator_list=["xgboost", "rf", "lgbm"])
    automl.model.estimator
    
    # Get the best model
    with open("automl.pkl", "wb") as f:
        pickle.dump(automl, f, pickle.HIGHEST_PROTOCOL)
           
    # At prediction time
    automl = pickle.load(open('automl.pkl', 'rb'))   
    predictions_auto = automl.predict(X_test)

    return predictions_auto

# %%
locations = ['A', 'B', 'C']
all_predictions_auto = []
all_predictions_cat = []

for loc in locations:
    train = pd.read_parquet(f'data/{loc}/train_targets.parquet').fillna(0)
    X_train_estimated = pd.read_parquet(f'data/{loc}/X_train_estimated.parquet')
    X_train_observed = pd.read_parquet(f'data/{loc}/X_train_observed.parquet')
    X_test_estimated = pd.read_parquet(f'data/{loc}/X_test_estimated.parquet')

    X_train, X_test, is_day_feature, targets = preprocessing_std(train, X_train_observed, X_train_estimated, X_test_estimated)
    y_train = targets

    X_train=add_new_features(X_train)
    X_test=add_new_features(X_test)
    
    min_length = min(len(X_train), len(y_train))
    X_train, y_train = X_train.iloc[:min_length], y_train[:min_length]

    targets_lgb = add_time_features_std(targets, 'time')
    X_train_lgb = add_time_features_std(X_train, 'date_forecast')
    X_test_lgb = add_time_features_std(X_test, 'date_forecast')

    targets_cat = add_time_features_cat(targets, 'time')
    X_train_cat = add_time_features_cat(X_train, 'date_forecast')
    X_test_cat = add_time_features_cat(X_test, 'date_forecast')

    X_train_cat['dew_or_rime:idx'] = X_train_cat['dew_or_rime:idx'].astype(int)
    X_train_cat['is_in_shadow:idx'] = X_train_cat['is_in_shadow:idx'].astype(int)

    X_test_cat['dew_or_rime:idx'] = X_test_cat['dew_or_rime:idx'].astype(int)
    X_test_cat['is_in_shadow:idx'] = X_test_cat['is_in_shadow:idx'].astype(int)

   

#Training and predicting using catboost model

    model_cat = CatBoostRegressor(loss_function='MAE', learning_rate=0.1, verbose=200)
    
    param_grid = {
        'depth': [6, 8, 10],               # Tree depth
        'iterations': [100, 200, 300],     # Number of boosting iterations
        'l2_leaf_reg': [1, 3, 5],         # L2 regularization
    }

# Create a GridSearchCV object
    grid_search = GridSearchCV(estimator=model_cat, param_grid=param_grid, cv=5, scoring='neg_mean_absolute_error', verbose=2)

# Fit the GridSearchCV on your training data
    grid_search.fit(X_train_cat, targets_cat['pv_measurement'])

# Print the best hyperparameters and corresponding MAE score
    print("Best hyperparameters: ", grid_search.best_params_)
    print("Best MAE score: ", -grid_search.best_score_)

# Get the best model
    best_model_cat = grid_search.best_estimator_ 
    
# Best HP for locations: 
# Best hyperparameters: {'depth': 6, 'iterations': 300, 'l2_leaf_reg': 1} for A
# Best hyperparameters:  {'depth': 6, 'iterations': 200, 'l2_leaf_reg': 5} for B 
# Best hyperparameters:  {'depth': 6, 'iterations': 200, 'l2_leaf_reg': 5} for C

    predictions_cat = best_model_cat.predict(X_test_cat)
    adjusted_final_predictions_cat = predictions_cat * is_day_feature['is_day:idx']
    adjusted_final_predictions_cat = np.clip(adjusted_final_predictions_cat, 0, None)

    X_train_lgb = X_train_lgb.rename(columns = lambda x:re.sub('[^A-Za-z0-9_]+', '', x))
    X_test_lgb = X_test_lgb.rename(columns = lambda x:re.sub('[^A-Za-z0-9_]+', '', x))
    y_train = y_train.rename(columns = lambda x:re.sub('[^A-Za-z0-9_]+', '', x))

#Training and predicting auto tuned model (flaml)
    predictions_auto = process_location_flaml(X_train_lgb, y_train, X_test_lgb)
    adjusted_final_predictions_auto = predictions_auto * is_day_feature['is_day:idx']
    adjusted_final_predictions_auto = np.clip(adjusted_final_predictions_auto, 0, None)

    all_predictions_cat.append(adjusted_final_predictions_cat)
    all_predictions_auto.append([adjusted_final_predictions_auto])
# Out:
# C:\Users\Utente\AppData\Local\Temp\ipykernel_5220\670847310.py:21: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   estimated_resampled = estimated.set_index('date_forecast').resample('1H').mean().dropna(how='all').reset_index()
# C:\Users\Utente\AppData\Local\Temp\ipykernel_5220\670847310.py:22: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   test_resampled = test.set_index('date_forecast').resample('1H').mean().dropna(how='all').reset_index()
# C:\Users\Utente\AppData\Local\Temp\ipykernel_5220\3739894777.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = data.corr()
# {firs_date}, {second_date}
#            date_forecast  absolute_humidity_2m:gm3  air_density_2m:kgm3  \
# 0    2019-06-02 22:00:00                     7.700              1.22825
# 1    2019-06-02 23:00:00                     7.700              1.22350
# 2    2019-06-03 00:00:00                     7.875              1.21975
# 3    2019-06-03 01:00:00                     8.425              1.21800
# 4    2019-06-03 02:00:00                     8.950              1.21800
# ...                  ...                       ...                  ...
# 4389 2023-04-30 19:00:00                     4.550              1.27650
# 4390 2023-04-30 20:00:00                     4.500              1.27975
# 4391 2023-04-30 21:00:00                     4.500              1.28100
# 4392 2023-04-30 22:00:00                     4.500              1.28100
# 4393 2023-04-30 23:00:00                     4.500              1.28100
#
#       ceiling_height_agl:m  clear_sky_energy_1h:J  clear_sky_rad:W  \
# 0              1728.949951               0.000000            0.000
# 1              1689.824951               0.000000            0.000
# 2              1563.224976               0.000000            0.000
# 3              1283.425049             208.649994            0.750
# 4              1003.500000           32468.150391           23.100
# ...                    ...                    ...              ...
# 4389           1674.199951           84464.945312            4.225
# 4390           1762.400024            2270.875000            0.000
# 4391           1696.650024               0.000000            0.000
# 4392           1353.400024               0.000000            0.000
# 4393           1626.574951               0.000000            0.000
#
#       cloud_base_agl:m  dew_or_rime:idx  dew_point_2m:K  diffuse_rad:W  ...  \
# 0          1728.949951              0.0      280.299988          0.000  ...
# 1          1689.824951              0.0      280.299988          0.000  ...
# 2          1563.224976              0.0      280.649994          0.000  ...
# 3          1283.425049              0.0      281.674988          0.300  ...
# 4          1003.500000              0.0      282.500000         11.975  ...
# ...                ...              ...             ...            ...  ...
# 4389        542.700012              0.0      272.424988          2.825  ...
# 4390        546.400024              0.0      272.299988          0.000  ...
# 4391        548.349976              0.0      272.299988          0.000  ...
# 4392        527.775024              0.0      272.299988          0.000  ...
# 4393        526.525024              0.0      272.274994          0.000  ...
#
#       total_cloud_cover:p  visibility:m  wind_speed_10m:ms  \
# 0              100.000000  40386.476562              3.600
# 1              100.000000  33770.648438              3.350
# 2              100.000000  13595.500000              3.050
# 3              100.000000   2321.850098              2.725
# 4               99.224998  11634.799805              2.550
# ...                   ...           ...                ...
# 4389            96.699997  23417.074219              5.175
# 4390            94.525002  21084.050781              4.650
# 4391            95.675003  20792.500000              4.450
# 4392            98.875000  14158.099609              4.100
# 4393            99.699997  11872.299805              3.750
#
#       wind_speed_u_10m:ms  wind_speed_v_10m:ms  wind_speed_w_1000hPa:ms  \
# 
# 1                  0.0  ...           100.000000  33770.648438
# 2                  0.0  ...           100.000000  13595.500000
# 3                  0.0  ...           100.000000   2321.850098
# 4                  0.0  ...            99.224998  11634.799805
# ...                ...  ...                  ...           ...
# 34056              0.0  ...            96.699997  23417.074219
# 34057              0.0  ...            94.525002  21084.050781
# 34058              0.0  ...            95.675003  20792.500000
# 34059              0.0  ...            98.875000  14158.099609
# 34060              0.0  ...            99.699997  11872.299805
#
#        wind_speed_10m:ms  wind_speed_u_10m:ms  wind_speed_v_10m:ms  \
# 0                  3.600               -3.575               -0.500
# 1                  3.350               -3.350                0.275
# 2                  3.050               -2.950                0.750
# 3                  2.725               -2.600                0.875
# 4                  2.550               -2.350                0.925
# ...                  ...                  ...                  ...
# 34056              5.175                4.800                1.925
# 34057              4.650                4.025                2.300
# 34058              4.450                3.575                2.600
# 34059              4.100                3.175                2.550
# 34060              3.750                2.725                2.550
#
#        wind_speed_w_1000hPa:ms  time_dummy  time_delta  is_estimated  \
# 0                          0.0         0.0    0.000000             0
# 1                          0.0         0.0    0.000000             0
# 2                          0.0         0.0    0.000000             0
# 3                          0.0         0.0    0.000000             0
# 4                          0.0         0.0    0.000000             0
# ...                        ...         ...         ...           ...
# 34056                      0.0        19.0  -35.998611             1
# 34057                      0.0        20.0  -36.998611             1
# 34058                      0.0        21.0  -37.998611             1
# 34059                      0.0        22.0  -38.998611             1
# 34060                      0.0        23.0  -39.998611             1
#
#                 date_calc
# 0                     NaT
# 1                     NaT
# 2                     NaT
# 3                     NaT
# 4                     NaT
# ...                   ...
# 34056 2023-04-29 07:00:05
# 34057 2023-04-29 07:00:05
# 34058 2023-04-29 07:00:05
# 34059 2023-04-29 07:00:05
# 34060 2023-04-29 07:00:05
#
# [34061 rows x 48 columns]
# Pairs with strong correlation:
# clear_sky_energy_1h:J and clear_sky_rad:W have a correlation of 0.9880019338026744
# clear_sky_energy_1h:J and sun_elevation:d have a correlation of 0.9842286460326978
# clear_sky_rad:W and sun_elevation:d have a correlation of 0.996166698809568
# diffuse_rad:W and diffuse_rad_1h:J have a correlation of 0.9804015104876219
# direct_rad:W and direct_rad_1h:J have a correlation of 0.9835029209638088
# msl_pressure:hPa and pressure_100m:hPa have a correlation of 0.999735651841536
# msl_pressure:hPa and pressure_50m:hPa have a correlation of 0.999918983467751
# msl_pressure:hPa and sfc_pressure:hPa have a correlation of 0.999935877582783
# pressure_100m:hPa and pressure_50m:hPa have a correlation of 0.999915104950061
# pressure_100m:hPa and sfc_pressure:hPa have a correlation of 0.9996667493717436
# pressure_50m:hPa and sfc_pressure:hPa have a correlation of 0.9999159383392854
# time_dummy and time_delta have a correlation of -0.9831002177315827
# time_delta and is_estimated have a correlation of -0.9916972749788887
#
#
#             date_forecast  absolute_humidity_2m:gm3  air_density_2m:kgm3  \
# 0     2019-06-02 22:00:00                     7.700              1.22825
# 1     2019-06-02 23:00:00                     7.700              1.22350
# 2     2019-06-03 00:00:00                     7.875              1.21975
# 3     2019-06-03 01:00:00                     8.425              1.21800
# 4     2019-06-03 02:00:00                     8.950              1.21800
# ...                   ...                       ...                  ...
# 29663 2022-10-20 21:00:00                     5.575              1.28400
# 29664 2022-10-20 22:00:00                     5.350              1.28700
# 29665 2022-10-20 23:00:00                     5.200              1.29050
# 29666 2022-10-21 00:00:00                     5.000              1.29200
# 29667 2022-10-21 01:00:00                     5.000              1.29200
#
#        ceiling_height_agl:m  clear_sky_energy_1h:J  clear_sky_rad:W  \
# 0               1728.949951               0.000000             0.00
# 1               1689.824951               0.000000             0.00
# 2               1563.224976               0.000000             0.00
# 3               1283.425049             208.649994             0.75
# 4               1003.500000           32468.150391            23.10
# ...                     ...                    ...              ...
# 29663                   NaN               0.000000             0.00
# 29664                   NaN               0.000000             0.00
# 29665                   NaN               0.000000             0.00
# 29666                   NaN               0.000000             0.00
# 29667                   NaN               0.000000             0.00
#
#        cloud_base_agl:m  dew_or_rime:idx  dew_point_2m:K  diffuse_rad:W  ...  \
# 0           1728.949951              0.0      280.299988          0.000  ...
# 1           1689.824951              0.0      280.299988          0.000  ...
# 2           1563.224976              0.0      280.649994          0.000  ...
# 3           1283.425049              0.0      281.674988          0.300  ...
# 4           1003.500000              0.0      282.500000         11.975  ...
# ...                 ...              ...             ...            ...  ...
# 29663        686.900024              0.0      275.200012          0.000  ...
# 29664        149.500000              0.0      274.600006          0.000  ...
# 29665               NaN              0.0      274.174988          0.000  ...
# 29666               NaN              0.0      273.675018          0.000  ...
# 29667               NaN              0.0      273.600006          0.000  ...
#
#        t_1000hPa:K  total_cloud_cover:p  visibility:m  wind_speed_10m:ms  \
# 0       286.225006           100.000000  40386.476562              3.600
# 1       286.899994           100.000000  33770.648438              3.350
# 2       286.950012           100.000000  13595.500000              3.050
# 3       286.750000           100.000000   2321.850098              2.725
# 4       286.450012            99.224998  11634.799805              2.550
# ...            ...                  ...           ...                ...
# 29663   277.850006            19.500000  39001.398438              1.675
# 29664   277.475006             9.700000  35336.726562              1.400
# 29665   277.149994             4.525000  27164.625000              1.300
# 29666   276.700012             1.975000  29933.000000              1.400
# 29667   276.399994             0.500000  36795.000000              1.500
#
#        wind_speed_u_10m:ms  wind_speed_v_10m:ms  wind_speed_w_1000hPa:ms  \
# 0                   -3.575               -0.500                      0.0
# 1                   -3.350                0.275                      0.0
# 2                   -2.950                0.750                      0.0
# 3                   -2.600                0.875                      0.0
# 4                   -2.350                0.925                      0.0
# ...                    ...                  ...                      ...
# 29663                0.250                1.675                      0.0
# 29664                0.050                1.400                      0.0
# 29665               -0.175                1.300                      0.0
# 29666               -0.700                1.175                      0.0
# 29667               -1.100                1.000                      0.0
#
#        time_dummy  time_delta  is_estimated
# 0               0           0             0
# 1               0           0             0
# 2               0           0             0
# 3               0           0             0
# 4               0           0             0
# ...           ...         ...           ...
# 29663           0           0             0
# 29664           0           0             0
# 29665           0           0             0
# 29666           0           0             0
# 29667           0           0             0
#
# [29668 rows x 45 columns]
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# 0:	learn: 952.6390060	total: 111ms	remaining: 11s
# 99:	learn: 343.8621581	total: 569ms	remaining: 0us
# [CV] END .............depth=6, iterations=100, l2_leaf_reg=1; total time=   0.6s
# 0:	learn: 896.9724063	total: 4.56ms	remaining: 451ms
# 99:	learn: 334.7594291	total: 405ms	remaining: 0us
# [CV] END .............depth=6, iterations=100, l2_leaf_reg=1; total time=   0.4s
# 0:	learn: 899.0052421	total: 5.83ms	remaining: 578ms
# 99:	learn: 343.1351012	total: 413ms	remaining: 0us
# [CV] END .............depth=6, iterations=100, l2_leaf_reg=1; total time=   0.4s
# 0:	learn: 940.5395515	total: 5.08ms	remaining: 503ms
# 99:	learn: 354.5606336	total: 400ms	remaining: 0us
# [CV] END .............depth=6, iterations=100, l2_leaf_reg=1; total time=   0.4s
# 0:	learn: 952.2607169	total: 5.5ms	remaining: 544ms
# 99:	learn: 351.0416327	total: 425ms	remaining: 0us
# [CV] END .............depth=6, iterations=100, l2_leaf_reg
	remaining: 0us
# [CV] END ............depth=10, iterations=300, l2_leaf_reg=1; total time=  15.6s
# 0:	learn: 938.1007524	total: 56.1ms	remaining: 16.8s
# 200:	learn: 239.4206812	total: 11s	remaining: 5.42s
# ...
# 200:	learn: 26.6950755	total: 10.4s	remaining: 5.14s
# 299:	learn: 20.9168587	total: 15.4s	remaining: 0us
# [CV] END ............depth=10, iterations=300, l2_leaf_reg=3; total time=  15.5s
# 0:	learn: 142.4032011	total: 49.2ms	remaining: 14.7s
# 200:	learn: 24.7538279	total: 10.4s	remaining: 5.1s
# 299:	learn: 18.9361963	total: 15.3s	remaining: 0us
# [CV] END ............depth=10, iterations=300, l2_leaf_reg=3; total time=  15.4s
# 0:	learn: 153.7987342	total: 46.1ms	remaining: 13.8s
# 200:	learn: 27.7264897	total: 9.39s	remaining: 4.63s
# 299:	learn: 22.2073606	total: 14s	remaining: 0us
# [CV] END ............depth=10, iterations=300, l2_leaf_reg=3; total time=  14.1s
# 0:	learn: 151.2081959	total: 48.5ms	remaining: 14.5s
# 200:	learn: 26.2815385	total: 10.1s	remaining: 4.97s
# 299:	learn: 19.7309962	total: 14.8s	remaining: 0us
# [CV] END ............depth=10, iterations=300, l2_leaf_reg=5; total time=  14.8s
# 0:	learn: 131.5179676	total: 58.1ms	remaining: 17.4s
# 200:	learn: 23.2927878	total: 9.68s	remaining: 4.77s
# 299:	learn: 17.7629052	total: 14.6s	remaining: 0us
# [CV] END ............depth=10, iterations=300, l2_leaf_reg=5; total time=  14.7s
# 0:	learn: 146.0050273	total: 53.5ms	remaining: 16s
# 200:	learn: 27.3146389	total: 10s	remaining: 4.93s
# 299:	learn: 20.8105479	total: 14.8s	remaining: 0us
# [CV] END ............depth=10, iterations=300, l2_leaf_reg=5; total time=  14.8s
# 0:	learn: 142.4032011	total: 45.1ms	remaining: 13.5s
# 200:	learn: 25.9108092	total: 10.5s	remaining: 5.19s
# 299:	learn: 21.1499582	total: 15.4s	remaining: 0us
# [CV] END ............depth=10, iterations=300, l2_leaf_reg=5; total time=  15.7s
# 0:	learn: 153.7987342	total: 47.4ms	remaining: 14.2s
# 200:	learn: 27.6297412	total: 8.98s	remaining: 4.42s
# 299:	learn: 22.2202053	total: 13.6s	remaining: 0us
# [CV] END ............depth=10, iterations=300, l2_leaf_reg=5; total time=  13.6s
# 0:	learn: 146.5597914	total: 4.35ms	remaining: 866ms
# 199:	learn: 44.0073677	total: 728ms	remaining: 0us
# Best hyperparameters:  {'depth': 6, 'iterations': 200, 'l2_leaf_reg': 5}
# Best MAE score:  54.90289039030098
# [flaml.automl.logger: 11-12 19:49:56] {1679} INFO - task = regression
# [flaml.automl.logger: 11-12 19:49:56] {1690} INFO - Evaluation method: holdout
# [flaml.automl.logger: 11-12 19:49:56] {1788} INFO - Minimizing error metric: mae
# [flaml.automl.logger: 11-12 19:49:56] {1900} INFO - List of ML learners in AutoML Run: ['xgboost', 'rf', 'lgbm']
# [flaml.automl.logger: 11-12 19:49:56] {2218} INFO - iteration 0, current learner xgboost
# [flaml.automl.logger: 11-12 19:49:56] {2344} INFO - Estimated sufficient time budget=312s. Estimated necessary time budget=0s.
# [flaml.automl.logger: 11-12 19:49:56] {2391} INFO -  at 0.2s,	estimator xgboost's best error=127.9210,	best estimator xgboost's best error=127.9210
# [flaml.automl.logger: 11-12 19:49:56] {2218} INFO - iteration 1, current learner lgbm
# [flaml.automl.logger: 11-12 19:49:56] {2391} INFO -  at 0.2s,	estimator lgbm's best error=127.9984,	best estimator xgboost's best error=127.9210
# [flaml.automl.logger: 11-12 19:49:56] {2218} INFO - iteration 2, current learner xgboost
# [flaml.automl.logger: 11-12 19:49:56] {2391} INFO -  at 0.3s,	estimator xgboost's best error=127.9210,	best estimator xgboost's best error=127.9210
# [flaml.automl.logger: 11-12 19:49:56] {2218} INFO - iteration 3, current learner lgbm
# [flaml.automl.logger: 11-12 19:49:56] {2391} INFO -  at 0.3s,	estimator lgbm's best error=127.9984,	best estimator xgboost's best error=127.9210
# [flaml.automl.logger: 11-12 19:49:56] {2218} INFO - iteration 4, current learner rf
# [flaml.automl.logger: 11-12 19:49:56] {2391} INFO -  at 0.6s,	estimator rf's best error=75.3296,	best estimator rf's best error=75.3296
# [flaml.automl.logger: 11-12 19:49:56] {2218} INFO - iteration 5, current learner xgboost
# [flaml.automl.logger: 11-12 19:49:56] {2391} INFO -  at 0.6s,	estimator xgboost's best error=88.7392,	best estimator rf's best error=75.3296
# [flaml.automl.logger: 11-12 19:49:56] {2218} INFO - iteration 6, current learner xgboost
# [flaml.automl.logger: 11-12 19:49:56] {2391} INFO -  at 0.6s,	estimator xgboost's best error=68.6071,	best estimator xgboost's best error=68.6071
# [flaml.automl.logger: 11-12 19:49:56] {2218} INFO - iteration 7, current learner xgboost
# [flaml.automl.logger: 11-12 19:49:56] {2391} INFO -  at 0.7s,	estimator xgboost's best error=68.6071,	best estimator xgboost's best error=68.6071
# [flaml.automl.logger: 11-12 19:49:56] {2218} INFO - iteration 8, current learner xgboost
# [flaml.automl.logger: 11-12 19:49:56] {2391} INFO -  at 0.7s,	estimator xgboost's best error=67.5041,	best estimator xgboost's best error=67.5041
# [flaml.automl.logger: 11-12 19:49:56] {2218} INFO - iteration 9, current learner xgboost
# [flaml.automl.logger: 11-12 19:49:56] {2391} INFO -  at 0.8s,	estimator xgboost's best error=60.4237,	best estimator xgboost's best error=60.4237
# [flaml.automl.logger: 11-12 19:49:56] {2218} INFO - iteration 10, current learner xgboost
# [flaml.automl.logger: 11-12 19:49:56] {2391} INFO -  at 0.8s,	estimator xgboost's best error=57.1228,	best estimator xgboost's best error=57.1228
# [flaml.automl.logger: 11-12 19:49:56] {2218} INFO - iteration 11, current learner xgboost
# [flaml.automl.logger: 11-12 19:49:56] {2391} INFO -  at 0.9s,	estimator xgboost's best error=56.9988,	best estimator xgboost's best error=56.9988
# [flaml.automl.logger: 11-12 19:49:56] {2218} INFO - iteration 12, current learner xgboost
# [flaml.automl.logger: 11-12 19:49:56] {2391} INFO -  at 1.0s,	estimator xgboost's best error=54.3366,	best estimator xgboost's best error=54.3366
# [flaml.automl.logger: 11-12 19:49:56] {2218} INFO - iteration 13, current learner xgboost
# [flaml.automl.logger: 11-12 19:49:56] {2391} INFO -  at 1.0s,	estimator xgboost's best error=54.3366,	best estimator xgboost's best error=54.3366
# [flaml.automl.logger: 11-12 19:49:56] {2218} INFO - iteration 14, current learner lgbm
# [flaml.automl.logger: 11-12 19:49:56] {2391} INFO -  at 1.1s,	estimator lgbm's best error=88.2984,	best estimator xgboost's best error=54.3366
# [flaml.automl.logger: 11-12 19:49:56] {2218} INFO - iteration 15, current learner xgboost
# [flaml.automl.logger: 11-12 19:49:57] {2391} INFO -  at 1.1s,	estimator xgboost's best error=54.3366,	best estimator xgboost's best error=54.3366
# [flaml.automl.logger: 11-12 19:49:57] {2218} INFO - iteration 16, current learner lgbm
# [flaml.automl.logger: 11-12 19:49:57] {2391} INFO -  at 1.1s,	estimator lgbm's best error=59.6686,	best estimator xgboost's best error=54.3366
# [flaml.automl.logger: 11-12 19:49:57] {2218} INFO - iteration 17, current learner xgboost
# [flaml.automl.logger: 11-12 19:49:57] {2391} INFO -  at 1.2s,	estimator xgboost's best error=51.2043,	best estimator xgboost's best error=51.2043
# [flaml.automl.logger: 11-12 19:49:57] {2218} INFO - iteration 18, current learner lgbm
# [flaml.automl.logger: 11-12 19:49:57] {2391} INFO -  at 1.3s,	estimator lgbm's best error=59.6686,	best estimator xgboost's best error=51.2043
# [flaml.automl.logger: 11-12 19:49:57] {2218} INFO - iteration 19, current learner lgbm
# [flaml.automl.logger: 11-12 19:49:57] {2391} INFO -  at 1.3s,	estimator lgbm's best error=59.1659,	best estimator xgboost's best error=51.2043
# [flaml.automl.logger: 11-12 19:49:57] {2218} INFO - iteration 20, current learner rf
# [flaml.automl.logger: 11-12 19:49:57] {2391} INFO -  at 1.7s,	estimator rf's best error=60.8743,	best estimator xgboost's best error=51.2043
# [flaml.automl.logger: 11-12 19:49:57] {2218} INFO - iteration 21, current learner xgboost
# [flaml.automl.logger: 11-12 19:49:57] {2391} INFO -  at 1.7s,	estimator xgboost's best error=51.2043,	best estimator xgboost's best error=51.2043
# [flaml.automl.logger: 11-12 19:49:57] {2218} INFO - iteration 22, current learner xgboost
# [flaml.automl.logger: 11-12 19:49:57] {2391} INFO -  at 1.9s,	estimator xgboost's best error=51.2043,	best estimator xgboost's best error=51.2043
# [flaml.automl.logger: 11-12 19:49:57] {2218} INFO - iteration 23, current learner rf
# [flaml.automl.logger: 11-12 19:49:58] {2391} INFO -  at 2.1s,	estimator rf's best error=60.8743,	best estimator xgboost's best error=51.2043
# [flaml.automl.logger: 11-12 19:49:58] {2218} INFO - iteration 24, current learner lgbm
# [flaml.automl.logger: 11-12 19:49:58] {2391} INFO -  at 2.2s,	estimator lgbm's best error=59.1659,	best estimator xgboost's best error=51.2043
# [flaml.automl.logger: 11-12 19:49:58] {2218} INFO - iteration 25, current learner xgboost
# [flaml.automl.logger: 11-12 19:49:58] {2391} INFO -  at 2.2s,	estimator xgboost's best error=51.2043,	best estimator xgboost's best error=51.2043
# [flaml.automl.logger: 11-12 19:49:58] {2218} INFO - iteration 26, current learner rf
# [flaml.automl.logger: 11-12 19:49:58] {2391} INFO -  at 2.8s,	estimator rf's best error=56.5006,	best estimator xgboost's best error=51.2043
# [flaml.automl.logger: 11-12 19:49:58] {2218} INFO - iteration 27, current learner rf
# [flaml.automl.logger: 11-12 19:49:59] {2391} INFO -  at 3.5s,	estimator rf's best error=54.0986,	best estimator xgboost's best error=51.2043
# [flaml.automl.logger: 11-12 19:49:59] {2218} INFO - iteration 28, current learner rf
# [flaml.automl.logger: 11-12 19:49:59] {2391} INFO -  at 4.0s,	estimator rf's best error=54.0986,	best estimator xgboost's best error=51.2043
# [flaml.automl.logger: 11-12 19:49:59] {2218} INFO - iteration 29, current learner xgboost
# [flaml.automl.logger: 11-12 19:50:00] {2391} INFO -  at 4.2s,	estimator xgboost's best error=50.7537,	best estimator xgboost's best error=50.7537
# [flaml.automl.logger: 11-12 19:50:00] {2218} INFO - iteration 30, current learner xgboost
# [flaml.automl.logger: 11-12 19:50:00] {2391} INFO -  at 4.3s,	estimator xgboost's best error=50.7537,	best estimator xgboost's best error=50.7537
# [flaml.automl.logger: 11-12 19:50:00] {2218} INFO - iteration 31, current learner xgboost
# [flaml.automl.logger: 11-12 19:50:00] {2391} INFO -  at 4.7s,	estimator xgboost's best error=45.7787,	best estimator xgboost's best error=45.7787
# [flaml.automl.logger: 11-12 19:50:00] {2218} INFO - iteration 32, current learner rf
# [flaml.automl.logger: 11-12 19:50:01] {2391} INFO -  at 5.6s,	estimator rf's best error=51.8054,	best estimator xgboost's best error=45.7787
# [flaml.automl.logger: 11-12 19:50:01] {2218} INFO - iteration 33, current learner xgboost
# [flaml.automl.logger: 11-12 19:50:01] {2391} INFO -  at 5.7s,	estimator xgboost's best error=45.7787,	best estimator xgboost's best error=45.7787
# [flaml.automl.logger: 11-12 19:50:01] {2218} INFO - iteration 34, current learner xgboost
# [flaml.automl.logger: 11-12 19:50:08] {2391} INFO -  at 12.8s,	estimator xgboost's best error=42.9667,	best estimator xgboost's best error=42.9667
# [flaml.automl.logger: 11-12 19:50:08] {2218} INFO - iteration 35, current learner lgbm
# [flaml.automl.logger: 11-12 19:50:08] {2391} INFO -  at 12.8s,	estimator lgbm's best error=59.1659,	best estimator xgboost's best error=42.9667
# [flaml.automl.logger: 11-12 19:50:08] {2218} INFO - iteration 36, current learner rf
# [flaml.automl.logger: 11-12 19:50:09] {2391} INFO -  at 13.5s,	estimator rf's best error=51.8054,	best estimator xgboost's best error=42.9667
# [flaml.automl.logger: 11-12 19:50:09] {2218} INFO - iteration 37, current learner lgbm
# [flaml.automl.logger: 11-12 19:50:09] {2391} INFO -  at 13.5s,	estimator lgbm's best error=55.1458,	best estimator xgboost's best error=42.9667
# [flaml.automl.logger: 11-12 19:50:09] {2218} INFO - iteration 38, current learner lgbm
# [flaml.automl.logger: 11-12 19:50:09] {2391} INFO -  at 13.6s,	estimator lgbm's best error=55.1458,	best estimator xgboost's best error=42.9667
# [flaml.automl.logger: 11-12 19:50:09] {2218} INFO - iteration 39, current learner lgbm
# [flaml.automl.logger: 11-12 19:50:09] {2391} INFO -  at 13.7s,	estimator lgbm's best error=46.2473,	best estimator xgboost's best error=42.9667
# [flaml.automl.logger: 11-12 19:50:09] {2218} INFO - iteration 40, current learner lgbm
# [flaml.automl.logger: 11-12 19:50:09] {2391} INFO -  at 13.9s,	estimator lgbm's best error=46.2473,	best estimator xgboost's best error=42.9667
# [flaml.automl.logger: 11-12 19:50:09] {2218} INFO - iteration 41, current learner xgboost
# [flaml.automl.logger: 11-12 19:50:12] {2391} INFO -  at 16.4s,	estimator xgboost's best error=42.9667,	best estimator xgboost's best error=42.9667
# [flaml.automl.logger: 11-12 19:50:12] {2218} INFO - iteration 42, current learner lgbm
# [flaml.automl.logger: 11-12 19:50:12] {2391} INFO -  at 16.5s,	estimator lgbm's best error=46.2473,	best estimator xgboost's best error=42.9667
# [flaml.automl.logger: 11-12 19:50:12] {2218} INFO - iteration 43, current learner lgbm
# [flaml.automl.logger: 11-12 19:50:12] {2391} INFO -  at 16.6s,	estimator lgbm's best error=46.2473,	best estimator xgboost's best error=42.9667
# [flaml.automl.logger: 11-12 19:50:12] {2218} INFO - iteration 44, current learner lgbm
# [flaml.automl.logger: 11-12 19:50:12] {2391} INFO -  at 16.8s,	estimator lgbm's best error=45.3177,	best estimator xgboost's best error=42.9667
# [flaml.automl.logger: 11-12 19:50:12] {2218} INFO - iteration 45, current learner rf
# [flaml.automl.logger: 11-12 19:50:13] {2391} INFO -  at 17.7s,	estimator rf's best error=50.6148,	best estimator xgboost's best error=42.9667
# [flaml.automl.logger: 11-12 19:50:13] {2218} INFO - iteration 46, current learner lgbm
# [flaml.automl.logger: 11-12 19:50:14] {2391} INFO -  at 18.1s,	estimator lgbm's best error=45.3177,	best estimator xgboost's best error=42.9667
# [flaml.automl.logger: 11-12 19:50:14] {2218} INFO - iteration 47, current learner xgboost
# [flaml.automl.logger: 11-12 19:50:36] {2391} INFO -  at 40.2s,	estimator xgboost's best error=42.9667,	best estimator xgboost's best error=42.9667
# [flaml.automl.logger: 11-12 19:50:36] {2218} INFO - iteration 48, current learner lgbm
# [flaml.automl.logger: 11-12 19:50:36] {2391} INFO -  at 40.3s,	estimator lgbm's best error=45.3177,	best estimator xgboost's best error=42.9667
# [flaml.automl.logger: 11-12 19:50:36] {2218} INFO - iteration 49, current learner lgbm
# [flaml.automl.logger: 11-12 19:50:36] {2391} INFO -  at 40.9s,	estimator lgbm's best error=45.3177,	best estimator xgboost's best error=42.9667
# [flaml.automl.logger: 11-12 19:50:36] {2218} INFO - iteration 50, current learner rf
# [flaml.automl.logger: 11-12 19:50:37] {2391} INFO -  at 41.8s,	estimator rf's best error=50.6148,	best estimator xgboost's best error=42.9667
# [flaml.automl.logger: 11-12 19:50:37] {2218} INFO - iteration 51, current learner rf
# [flaml.automl.logger: 11-12 19:50:38] {2391} INFO -  at 42.8s,	estimator rf's best error=50.6148,	best estimator xgboost's best error=42.9667
# [flaml.automl.logger: 11-12 19:50:38] {2218} INFO - iteration 52, current learner xgboost
# [flaml.automl.logger: 11-12 19:51:06] {2391} INFO -  at 70.4s,	estimator xgboost's best error=42.9667,	best estimator xgboost's best error=42.9667
# [flaml.automl.logger: 11-12 19:51:13] {2627} INFO - retrain xgboost for 7.1s
# [flaml.automl.logger: 11-12 19:51:13] {2630} INFO - retrained model: XGBRegressor(base_score=None, booster=None, callbacks=[],
#              colsample_bylevel=0.5402300960155632, colsample_bynode=None,
#              colsample_bytree=0.6180077929405803, device=None,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, feature_types=None, gamma=None,
#              grow_policy='lossguide', importance_type=None,
#              interaction_constraints=None, learning_rate=0.0917772113853677,
#              max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=0, max_leaves=305,
#              min_child_weight=0.9894761152832849, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=117,
#              n_jobs=-1, num_parallel_tree=None, random_state=None, ...)
# [flaml.automl.logger: 11-12 19:51:13] {1930} INFO - fit succeeded
# [flaml.automl.logger: 11-12 19:51:13] {1931} INFO - Time taken to find the best model: 12.785922527313232

# %%
all_predictions_auto = np.array(all_predictions_auto).flatten()
all_predictions_cat = np.array(all_predictions_cat).flatten()

# %%
all_pred = 0.15*all_predictions_auto  +  0.85*all_predictions_cat
print(all_pred.shape)

final_predictions = all_pred

# Save the final_predictions to CSV
df = pd.DataFrame(final_predictions, columns=['prediction'])
df['id'] = df.index
df = df[['id', 'prediction']]
df.to_csv('final_predictions_cat_main.csv', index=False)

plt.figure(figsize=(8, 6))
plt.plot(range(len(final_predictions)), final_predictions,  c='blue', label='Predicted')
plt.xlabel('Index')
plt.ylabel('Predicted Values')
plt.legend(loc='upper left')

plt.show()
# Out:
# (2160,)
